# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('RBI.csv').transpose()
df1.reset_index()
df1.columns = df1.iloc[0]
df1.drop(df1.index[0], inplace=True)
df1.reset_index(inplace=True)
df1.rename(columns={'index': 'Year'}, inplace=True)
df1.fillna(0, inplace=True)
df1 = df1.astype('float64')
df1['Year'] = df1['Year'].astype('category')

# %%
df1
# Out:
# Ratio    Year  Working Capital  Current Ratio  Quick Ratio  \
# 0      2015.0            249.0           1.22         1.05
# 1      2016.0            886.0           1.73         1.54
# 2      2017.0             95.0           1.06         0.96
# 3      2018.0             92.0           1.07         0.97
# 4      2019.0            493.0           1.29         1.21
#
# Ratio  Inventory Turnover  Days Inv  AR Turnover  Days AR  \
# 0                    22.0      16.0          9.6     38.0
# 1                    23.0      16.0         10.0     36.0
# 2                    25.0      15.0         10.3     36.0
# 3                    24.0      15.0         11.4     32.0
# 4                    23.0      16.0         11.4     32.0
#
# Ratio  Fixed Asset Turnover  Total Assets Turnover  ...  Profit Margin   ROA  \
# 0                      1.88                   0.22  ...           0.13  0.03
# 1                      1.97                   0.22  ...           0.23  0.05
# ...

# %%
df1['AdjustedROA'] = [ 0.07, 0.10, 0.13, 0.13, 0.09]

# %%
df1
# Out:
# Ratio    Year  Working Capital  Current Ratio  Quick Ratio  \
# 0      2015.0            249.0           1.22         1.05
# 1      2016.0            886.0           1.73         1.54
# 2      2017.0             95.0           1.06         0.96
# 3      2018.0             92.0           1.07         0.97
# 4      2019.0            493.0           1.29         1.21
#
# Ratio  Inventory Turnover  Days Inv  AR Turnover  Days AR  \
# 0                    22.0      16.0          9.6     38.0
# 1                    23.0      16.0         10.0     36.0
# 2                    25.0      15.0         10.3     36.0
# 3                    24.0      15.0         11.4     32.0
# 4                    23.0      16.0         11.4     32.0
#
# Ratio  Fixed Asset Turnover  Total Assets Turnover  ...   ROA   ROE  \
# 0                      1.88                   0.22  ...  0.03  0.18
# 1                      1.97                   0.22  ...  0.05  0.20
# ...

# %%
df2 = pd.read_csv('MacD.csv').transpose()
df2.reset_index()
df2.columns = df2.iloc[0]
df2.drop(df2.index[0], inplace=True)
df2.reset_index(inplace=True)
df2.rename(columns={'index': 'Year'}, inplace=True)
df2.fillna(0, inplace=True)
df2 = df2.astype('float64')
df2['Year'] = df2['Year'].astype('category')

# %%
df2
# Out:
# Ratio    Year  Total Sales  Revenue Owned  Revenue Franchise  Gross Margin  \
# 0      2015.0      25413.0        16488.3             8924.7          0.72
# 1      2016.0      24621.9        15295.0             9326.9          0.73
# 2      2017.0      22820.4        12718.9            10101.5          0.74
# 3      2018.0      21025.2        10012.7            11012.5          0.76
# 4      2019.0      21076.5         9420.8            11655.7          0.75
#
# Ratio  EBIT Margin  Profit Margin  Current Ratio   ROA   ROE  Debt-toEquity  \
# 0             0.23           0.18           3.27  0.13  0.25           1.96
# 1             0.24           0.19           1.40  0.14  1.39          10.25
# 2             0.34           0.23           1.84  0.16 -1.62         -10.14
# 3             0.33           0.28           1.36  0.18 -1.13          -6.36
# 4             0.33           0.29           0.98  0.15 -0.82          -5.43
#
# ...

# %%
df3 = pd.read_csv('Yum.csv').transpose()
df3.reset_index()
df3.columns = df3.iloc[0]
df3.drop(df3.index[0], inplace=True)
df3.reset_index(inplace=True)
df3.rename(columns={'index': 'Year'}, inplace=True)
df3.fillna(0, inplace=True)
df3 = df3.astype('float64')
df3['Year'] = df3['Year'].astype('category')

# %%
df3
# Out:
# Ratio    Year  Total Sales  Revenue Owned  Revenue Franchise  Gross Margin  \
# 0      2015.0       6418.0         4336.0             2082.0          0.69
# 1      2016.0       6356.0         4189.0             2167.0          0.42
# 2      2017.0       5878.0         3572.0             2306.0          0.46
# 3      2018.0       5688.0         2000.0             3688.0          0.68
# 4      2019.0       5597.0         1546.0             4051.0          0.75
#
# Ratio  EBIT Margin  Profit Margin  Current Ratio   ROA   ROE  Debt-toEquity  \
# 0             0.22           0.20           0.55  0.13  0.38           2.96
# 1             0.26           0.26           1.15  0.19 -0.53          -2.77
# 2             0.46           0.23           1.66  0.31 -0.48          -1.58
# 3             0.40           0.27           0.93  0.28 -0.40          -1.39
# 4             0.33           0.23           0.99  0.33 -0.43          -1.29
#
# ...

# %%
df4 = pd.read_csv('SBUX.csv').transpose()
df4.reset_index()
df4.columns = df4.iloc[0]
df4.drop(df4.index[0], inplace=True)
df4.reset_index(inplace=True)
df4.rename(columns={'index': 'Year'}, inplace=True)
df4.fillna(0, inplace=True)
df4 = df4.astype('float64')
df4['Year'] = df4['Year'].astype('category')

# %%
df4
# Out:
# Ratio    Year  Total Sales  Revenue Owned  Revenue Franchise  Gross Margin  \
# 0      2015.0      19163.0        15197.0             1862.0          0.59
# 1      2016.0      21316.0        16844.0             2154.0          0.60
# 2      2017.0      22387.0        17651.0             2355.0          0.68
# 3      2018.0      24720.0        19690.0             2652.0          0.68
# 4      2019.0      26509.0        21544.0             2875.0          0.68
#
# Ratio  EBIT Margin  Profit Margin  Current Ratio   ROA   ROE  Debt-toEquity  \
# 0             0.21           0.14           1.09  0.21  0.08           0.40
# 1             0.20           0.13           1.05  0.23  0.12           0.51
# 2             0.20           0.13           1.25  0.21  0.14           0.66
# 3             0.24           0.18           2.20  0.17  0.33           2.02
# 4             0.17           0.14           0.92  0.22 -0.91          -4.07
#
# ...

# %%
sns.lineplot(x='Year', y='Current Ratio', data=df1)
sns.lineplot(x='Year', y='Current Ratio', data=df2)
plt.legend(['RBI', 'MCD'])
plt.xticks([2014, 2015, 2016,2017,2018,2019])
plt.title('Solvency Ratios')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
figure3 = plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(df1['Total Assets Turnover'], linewidth=4, color='orange', linestyle='dashdot')
plt.plot(df2['Total Asset Turnover'], linewidth=3, color = 'goldenrod')
plt.plot(df3['Total Asset Turnover'], linewidth=3, color = 'red')
plt.plot(df4['Total Asset Turnover'], linewidth=3, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.yticks(fontsize=9)
plt.title('Total Assets Turnover', fontsize=12)

plt.subplot(1,2,2)
plt.plot(df1['Fixed Asset Turnover'], linewidth=4, color='orange', linestyle='dashdot')
plt.plot(df2['Fixed Asset Turnover'], linewidth=3, color = 'goldenrod')
plt.plot(df3['Fixed Asset Turnover'], linewidth=3, color = 'red')
plt.plot(df4['Fixed Asset Turnover'], linewidth=3, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=8)
plt.yticks(fontsize=9)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.title('Fixed Asset Turnover', fontsize=12)
figure3.savefig('figure3', bbox_inches = 'tight')

# %% [markdown]
# DONE

# %%
sns.lineplot(x='Year', y='Current Ratio', data=df1, color='orange')
sns.lineplot(x='Year', y='Current Ratio', data=df2, color = 'y')
sns.lineplot(x='Year', y='Current Ratio', data=df3, color = 'r')
sns.lineplot(x='Year', y='Current Ratio', data=df4, color='g')
plt.legend(['RBI', 'MCD', 'Yum', 'SBUX'])
plt.title('Current Ratio - Close Competitors')
# Out:
# Text(0.5, 1.0, 'Current Ratio - Close Competitors')

# %% [markdown]
# Sales of competitors

# %%
figure4 = plt.figure(figsize=(10,7))

plt.subplot(2,2,1)
plt.plot(df1['Revenue Owned'], linewidth=3)
plt.plot(df1['Revenue Franchise'],linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=8)
plt.legend(['Store Owned Revenue','Franchise Revenue'], prop={'size' : 9})
plt.ylabel('($M)', fontsize=10)
plt.title('RBI', fontsize=12)

plt.subplot(2,2,2)
plt.plot(df2['Revenue Owned'], linewidth=3)
plt.plot(df2['Revenue Franchise'],linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=8)
plt.legend(['Store Owned Revenue','Franchise Revenue'], prop={'size' : 9})
plt.ylabel('($M)', fontsize=10)
plt.title("McDonald's", fontsize=12)

plt.subplot(2,2,3)
plt.plot(df3['Revenue Owned'], linewidth=3)
plt.plot(df3['Revenue Franchise'],linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=8)
plt.legend(['Store Owned Revenue','Franchise Revenue'], prop={'size' : 9})
plt.yticks(fontsize=8)
plt.ylabel('($M)', fontsize=10)
plt.title('Yum!', fontsize=12)

plt.subplot(2,2,4)
plt.plot(df4['Revenue Owned'], linewidth=3)
plt.plot(df4['Revenue Franchise'],linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=8)
plt.legend(['Store Owned Revenue','Franchise Revenue'], prop={'size' : 9})
plt.yticks(fontsize=8)
plt.ylabel('($M)', fontsize=10)
plt.title('Starbucks', fontsize=12)
figure4.savefig('figure4', bbox_inches = 'tight')

# %% [markdown]
# Margins

# %%
fig = plt.figure(figsize=(15,15))

plt.subplot(2,2,1)
plt.plot(df1['Gross Margin'], linewidth=4, color='orange', linestyle='dashdot')
plt.plot(df2['Gross Margin'], linewidth=3, color = 'yellow')
plt.plot(df3['Gross Margin'], linewidth=3, color = 'red')
plt.plot(df4['Gross Margin'], linewidth=3, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=15)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 15}, loc='lower right')
plt.ylim([0,1])
plt.yticks(fontsize=15)
plt.title('Gross Margin - Competition', fontsize=15)

plt.subplot(2,2,2)
plt.plot(df1['EBIT Margin'], linewidth=4, color='orange', linestyle='dashdot')
plt.plot(df2['EBIT Margin'], linewidth=3, color = 'yellow')
plt.plot(df3['EBIT Margin'], linewidth=3, color = 'red')
plt.plot(df4['EBIT Margin'], linewidth=3, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([0,1])
plt.title('EBIT Margin - Competition', fontsize=15)

plt.subplot(2,2,3)
plt.plot(df1['Profit Margin'], linewidth=4, color='orange', linestyle='dashdot')
plt.plot(df2['Profit Margin'], linewidth=3, color = 'yellow')
plt.plot(df3['Profit Margin'], linewidth=3, color = 'red')
plt.plot(df4['Profit Margin'], linewidth=3, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=15)
plt.yticks(fontsize=15)
plt.ylim([0,1])
plt.title('Profit Margin - Competition', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Profit Margin - Competition')

# %%
figure7 = plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(df1['Current Ratio'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Current Ratio'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Current Ratio'], linewidth=2, color = 'red')
plt.plot(df4['Current Ratio'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10})
plt.ylim([0,4])
plt.yticks(fontsize=10)
plt.title('Current Ratio - Competition', fontsize=12)

plt.subplot(1,2,2)
plt.plot(df1['Quick Ratio'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Quick Ratio'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Quick Ratio'], linewidth=2, color = 'red')
plt.plot(df4['Quick Ratio'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10})
plt.ylim([0,4])
plt.yticks(fontsize=10)
plt.title('Quick Ratio - Competition', fontsize=12)

figure7.savefig('figure7', bbox_inches = 'tight')

# %%
fig = plt.figure(figsize = (6,12))

plt.subplot(2,1,1)
plt.plot(df1['ROA'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['ROA'], linewidth=2, color = 'yellow')
plt.plot(df3['ROA'], linewidth=2, color = 'red')
plt.plot(df4['ROA'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim([0,0.5])
plt.yticks(fontsize=12)
plt.title('Rerturn on Assets - Competition', fontsize=12)

plt.subplot(2,1,2)
plt.plot(df1['ROE'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['ROE'], linewidth=2, color = 'yellow')
plt.plot(df3['ROE'], linewidth=2, color = 'red')
plt.plot(df4['ROE'], linewidth=2, color = 'green', alpha = 0.5)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.yticks(fontsize=12)
plt.title('Return on Equity - Competition', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Return on Equity - Competition')

# %%
figure10 = plt.figure(figsize = (15,4))

plt.subplot(1,3,1)
plt.plot(df1['ROA'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['ROA'], linewidth=2, color = 'goldenrod')
plt.plot(df3['ROA'], linewidth=2, color = 'red')
plt.plot(df4['ROA'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylim([0,0.5])
plt.yticks(fontsize=12)
plt.title('Rerturn on Assets', fontsize=12)

plt.subplot(1,3,2)
plt.plot(df1['Adjusted ROA'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['ROA'], linewidth=2, color = 'goldenrod')
plt.plot(df3['ROA'], linewidth=2, color = 'red')
plt.plot(df4['ROA'], linewidth=2, color = 'green', alpha = 0.5)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.yticks(fontsize=12)
plt.ylim([0,0.5])
plt.title('Return on Assets (adjusted)', fontsize=12)

plt.subplot(1,3,3)
plt.plot(df1['ROE'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['ROE'], linewidth=2, color = 'goldenrod')
plt.plot(df3['ROE'], linewidth=2, color = 'red')
plt.plot(df4['ROE'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.title('Rerturn on Equity', fontsize=12)

figure10.tight_layout(pad=3.0)

figure10.savefig('figure9', bbox_inches = 'tight')

# %%
figure10 = plt.figure()
plt.plot(df1['ROE'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['ROE'], linewidth=2, color = 'goldenrod')
plt.plot(df3['ROE'], linewidth=2, color = 'red')
plt.plot(df4['ROE'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.title('Rerturn on Equity', fontsize=12)
figure10.savefig('figure10', bbox_inches = 'tight')

# %%
fig = plt.figure(figsize = (15, 15))

plt.subplot(2,2,1)
plt.plot(df1['Days AR'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Days AR'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Days AR'], linewidth=2, color = 'red')
plt.plot(df4['Days AR'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.yticks(fontsize=12)
plt.title('Days AR', fontsize=12)

plt.subplot(2,2,2)
plt.plot(df1['Days Inv'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Days Inv'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Days Inv'], linewidth=2, color = 'red')
plt.plot(df4['Days Inv'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.title('Days Inventory', fontsize=12)


plt.subplot(2,2,3)
plt.plot(df1['Days Payable'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Days Payable'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Days Payable'], linewidth=2, color = 'red')
plt.plot(df4['Days Payable'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.yticks(fontsize=12)
plt.title('Days Payable', fontsize=12)

plt.subplot(2,2,4)
plt.plot(df1['Cash conversion cycle'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Cash conversion cycle'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Cash conversion cycle'], linewidth=2, color = 'red')
plt.plot(df4['Cash conversion cycle'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.title('Cash conversion cycle', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Cash conversion cycle')

# %%
plt.plot(df1['Cash conversion cycle'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Cash conversion cycle'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Cash conversion cycle'], linewidth=2, color = 'red')
plt.plot(df4['Cash conversion cycle'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.ylabel('Number of Days')
plt.xlabel('Year')
plt.title('Cash conversion cycle', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Cash conversion cycle')

# %%
(df1['Return on Assets'].tail(4))

# %%
df3

# %%
sns.lineplot(x='Year', y='Profit Margin', data=df1)
sns.lineplot(x='Year', y='Total Assets Turnover', data=df1)
sns.lineplot(x='Year', y='Return on Assets', data=df1)

sns.lineplot(x='Year', y='ROA', data=df2)
plt.legend(['Profit Margin', 'Total Asset Turnover', 'ROA', 'ROA MCD'])
plt.xticks([2014, 2015, 2016,2017,2018,2019])
plt.title("RBI vs. McDonald's")
plt.ylabel('')

# %%
sns.lineplot(x='Year', y='Profit Margin', data=df2)
sns.lineplot(x='Year', y='Total Assets Turnover', data=df2)
sns.lineplot(x='Year', y='Debt-to-Equity Ratio',color='r', data=df2)
sns.lineplot(x='Year', y='Return on Equity', data=df2)
plt.legend(['Profit Margin', 'Total Asset Turnover', 'Debt-to-Equity', 'Return on Equity'])
plt.xticks([2014, 2015, 2016,2017,2018,2019])
plt.title('Return on Equity - Oil Sands')
plt.ylabel('')

# %%
sns.barplot(x='Year', y='Profit Margin', data=df1)

# %%
sns.barplot(x='Year', y='Profit Margin', data=df2)

# %%
sns.barplot(x='Year', y='Total Assets Turnover', data=df1)

# %%
sns.barplot(x='Year', y='Total Assets Turnover', data=df2)

# %%
df1 = df1.groupby('Year', as_index=False).sum()

# %%
df1

# %%
sns.barplot(x='Year', y='Return on Assets', data=df1)

# %%
sns.barplot(x='Year', y='Profit Margin', data=df1)

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Dbet to Equity', color=color)
ax1.plot(df1['Debt-to-Equity Ratio'], color=color)
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Return on Equity', color=color)  # we already handled the x-label with ax1
ax2.plot(df1['Return on Equity'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Debt to Equity & Return on Equity - RBI')
plt.show()

# %%
sns.lineplot(x='Year', y='Sales', data=df1)
sns.lineplot(x='Year', y='COGS', data=df1)
plt.legend(['Sales', 'COGS'])
plt.xticks([2010, 2011,2012,2013,2014, 2015])
plt.title('Revenue vs. COGS - Oil Sands')
plt.ylabel('')

# %%
sns.lineplot(x='Year', y='Altman Z Score', data=df1)
sns.lineplot(x='Year', y='Mkt Value Equity / BV Liabilities', data=df1)
plt.legend(['Altman Z Score', 'Mkt Value Equity / BV Liabilities'])
plt.xticks([2010, 2011,2012,2013,2014, 2015])
plt.ylabel('')
plt.title('Oil Sands: Altman Z score compared to Market Value of Equity / BV Liabilities')

# %%
sns.lineplot(x='Year', y='P(default) - Olhson Score', data=df1)
sns.lineplot(x='Year', y='Debt-to-Equity Ratio', data=df1)
sns.lineplot(x='Year', y='CL / CS', data=df1)
plt.legend(['P(defualt)', 'Debt/Equity', 'Current Liabilities/Current Assets'])
plt.xticks([2010, 2011,2012,2013,2014, 2015])
plt.ylabel('')
plt.title('Oil Sands:Probabiliy of Default, Debt-to-Equity, CL / CA')

# %%
sns.lineplot(x='Year', y='Altman Z Score', data=df1)
sns.lineplot(x='Year', y='Z Score Suncor', data=df1)
plt.legend(['Oil Sands: Altman Z Score', 'Suncor: Altman Z Score'])
plt.xticks([2010, 2011,2012,2013,2014, 2015])
plt.ylabel('')
plt.title("Altman's Z score: Suncor v Oil Sands")

# %%
sns.lineplot(x='Year', y='P(default) - Olhson Score', data=df1)
sns.lineplot(x='Year', y='P score Suncor', data=df1)
plt.legend(['Oil Sands: P(default)', 'Suncor: P(default)'])
plt.xticks([2010, 2011,2012,2013,2014, 2015])
plt.ylabel('')
plt.title("Olhman's Probability of Default: Suncor v Oil Sands")

# %%
aa = pd.DataFrame({'Category':[6.76,6.76,6.76,6.76,6.76,6.76], 'Year': [2010, 2011,2012,2013,2014, 2015]})
a = pd.DataFrame({'Category':[5.2,5.2,5.2,5.2,5.2,5.2],'Year': [2010, 2011,2012,2013,2014, 2015]})
bbb = pd.DataFrame({'Category':[3.29,3.29,3.29,3.29,3.29,3.29],'Year': [2010, 2011,2012,2013,2014, 2015]})
bb = pd.DataFrame({'Category':[1.58,1.58,1.58,1.58,1.58,1.58],'Year': [2010, 2011,2012,2013,2014, 2015]})

# %%
sns.lineplot(x='Year', y='Suncor Kaplan Urwitz', data=df1)
sns.lineplot(x='Year', y='Oil Sands Kaplan Urwitz', data=df1)
sns.lineplot(x = 'Year', y = 'Category', data = aa, c='gray', dashes = True, markers=True)
sns.lineplot(x = 'Year', y = 'Category', data = a, c='gray')
sns.lineplot(x = 'Year', y = 'Category', data = bbb, c='gray')
sns.lineplot(x = 'Year', y = 'Category', data = bb, c='gray')
plt.legend(['Suncore', 'Oil Sands'], loc = 'upper left')
plt.xticks([2010, 2011,2012,2013,2014, 2015])
plt.ylabel('')
plt.title("Kaplan-Urwitz Score")

# %%
plt.plot(df1['Current Ratio'], linewidth=3)
plt.plot(df1['Quick Ratio'], linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019])
plt.legend()
plt.title('')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Days Payable')

# %%
figure2 = plt.figure()

plt.plot(df1['Cash conversion cycle'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Cash conversion cycle'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Cash conversion cycle'], linewidth=2, color = 'red')
plt.plot(df4['Cash conversion cycle'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.ylabel('Number of Days')
plt.xlabel('Year')
plt.title('Cash conversion cycle', fontsize=12)
figure2.savefig('figure2', bbox_inches = 'tight')

# %%
figure1 = plt.figure(figsize=(10,3))

plt.subplot(1,2,1)
plt.plot(df1['Days Payable'], linewidth=3)
plt.plot(df1['Days AR'], linewidth=3)
plt.plot(df1['Days Inv'], linewidth=3)
plt.plot(df1['Cash conversion cycle'], linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019])
plt.legend(['Days Payable', 'Days AR', 'Days Inventory', 'Cash Cycle'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylabel('Number of Days')
plt.xlabel('Year')
plt.title('RBI - Cash Cycle')

plt.subplot(1,2,2)
plt.plot(df1['Cash conversion cycle'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Cash conversion cycle'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Cash conversion cycle'], linewidth=2, color = 'red')
plt.plot(df4['Cash conversion cycle'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.ylabel('Number of Days')
plt.xlabel('Year')
plt.title('Cash conversion cycle', fontsize=12)
figure1.tight_layout(pad=1.0)

figure1.savefig('figure1.png', bbox_inches = 'tight')

# %%
plt.plot(df1['Current Ratio'], linewidth=3)
plt.plot(df1['Quick Ratio'], linewidth=3)
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019])
plt.legend(['Current Ratio', 'Quick Ratio'], loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.ylabel('Number of Days')
plt.xlabel('Year')
plt.ylim([0,2])
plt.title('RBI - Cash Cycle')
# Out:
# Text(0.5, 1.0, 'RBI - Cash Cycle')

# %%
plt.plot(df1['Fixed Asset Turnover'], linewidth=3)
plt.ylim([0,3])
# Out:
# (0, 3)

# %%
figure5 = plt.figure()
plt.plot(df1['Debt-to-Equity Ratio'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Debt-toEquity'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Debt-toEquity'], linewidth=2, color = 'red')
plt.plot(df4['Debt-toEquity'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.xlabel('Year')
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=10)
plt.ylim([-15,15])
plt.title('Debt-to-Equity', fontsize=13)
figure5.savefig('figure5', bbox_inches = 'tight')

# %%
df2.columns
# Out:
# Index(['Year', 'Total Sales', 'Revenue Owned', 'Revenue Franchise',
#        'Gross Margin', 'EBIT Margin', 'Profit Margin', 'Current Ratio', 'ROA',
#        'ROE', 'Debt-toEquity', 'Total Asset Turnover', 'Days AR', 'Days Inv',
#        'Days Payable', 'Cash conversion cycle'],
#       dtype='object', name='Ratio')

# %%
figure6 = plt.figure(figsize = (12,4))

plt.subplot(1,3,1)
plt.plot(df1['Debt-to-Equity Ratio'], linewidth=3, color='orange', linestyle='dashdot')
plt.plot(df2['Debt-toEquity'], linewidth=2, color = 'goldenrod')
plt.plot(df3['Debt-toEquity'], linewidth=2, color = 'red')
plt.plot(df4['Debt-toEquity'], linewidth=2, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.xlabel('Year')
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=10)
plt.ylim([-15,15])
plt.title('Debt-to-Equity', fontsize=13)

plt.subplot(1,3,2)
plt.plot(df1['Interest Coverage Ratio'], linewidth=4, color='orange', linestyle='dashdot')
plt.plot(df2['Interest Coverage Ratio'], linewidth=3, color = 'goldenrod')
plt.plot(df3['Interest Coverage Ratio'], linewidth=3, color = 'red', alpha = 0.3)
plt.plot(df4['Interest Coverage Ratio'], linewidth=3, color = 'green')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.legend(['RBI', 'MCD', 'Yum!', 'SBUX'], prop={'size' : 10}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.xlabel('Year')
plt.title('Interest Coverage Ratio - Peers')
plt.yticks(fontsize=10)

plt.subplot(1,3,3)
plt.plot(df1['Interest Coverage Ratio'], linewidth=4, color='orange', linestyle='dashdot')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=10)
plt.xlabel('Year')
plt.title('RBI Interest Coverage Ratio')
plt.yticks(fontsize=10)

figure6.tight_layout(pad=2.0)

figure6.savefig('figure6', bbox_inches = 'tight')

# %%
figure8 = plt.figure(figsize = (16, 8))
figure8.suptitle('Return on Assets Decomposition', fontsize=16)

plt.subplot(2,2,1)
plt.plot(df1['ROA'], linewidth=3, linestyle='dashdot', label='ROA')
plt.plot(df1['Profit Margin'], linewidth=2, label = 'Profit Margin')
plt.plot(df1['Total Assets Turnover'], linewidth=2, label = 'Total Asset Turnover')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.title('RBI', fontsize=14)

plt.subplot(2,2,2)
plt.plot(df2['ROA'], linewidth=3, linestyle='dashdot', label='ROA')
plt.plot(df2['Profit Margin'], linewidth=2, label = 'Profit Margin')
plt.plot(df2['Total Asset Turnover'], linewidth=2, label = 'Total Asset Turnover')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.yticks(fontsize=12)
plt.legend(prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.title("McDonald's", fontsize=14)


plt.subplot(2,2,3)
plt.plot(df3['ROA'], linewidth=3, linestyle='dashdot', label='ROA')
plt.plot(df3['Profit Margin'], linewidth=2, label = 'Profit Margin')
plt.plot(df3['Total Asset Turnover'], linewidth=2, label = 'Total Asset Turnover')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.title('Yum!', fontsize=14)

plt.subplot(2,2,4)
plt.plot(df4['ROA'], linewidth=3, linestyle='dashdot', label='ROA')
plt.plot(df4['Profit Margin'], linewidth=2, label = 'Profit Margin')
plt.plot(df4['Total Asset Turnover'], linewidth=2, label = 'Total Asset Turnover')
plt.xticks(range(5), [2015, 2016, 2017, 2018, 2019], fontsize=12)
plt.legend(prop={'size' : 12}, loc='upper left',bbox_to_anchor=(1.05, 1), borderaxespad=0.)
plt.yticks(fontsize=12)
plt.title('Starbucks', fontsize=14)

figure8.tight_layout(pad=4)

figure8.savefig('figure8', bbox_inches = 'tight')
